-- %% [markdown]
-- # Compaction using OPTIMIZE and Z-Ordering

-- %% [markdown]
-- ## OPTIMIZE Command
-- Merges multiple small files into fewer, larger files, thus improves the performance

-- %% [markdown]
-- ### 1. Create table - demo.delta_lake.optimize_Stock_prices

-- %%
DROP TABLE IF EXISTS demo.delta_lake.optimize_stock_prices;

CREATE TABLE IF NOT EXISTS demo.delta_lake.optimize_stock_prices (
    stock_id STRING,
    price DOUBLE,
    trading_date DATE
);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- ### 2.Inserts some data in a few transactions

-- %%
INSERT INTO demo.delta_lake.optimize_stock_prices
VALUES ('AAPL', 227.65, "2025-02-10");
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

-- %%
INSERT INTO demo.delta_lake.optimize_stock_prices
VALUES ('GOOGL', 2775.0, "2025-02-10");
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

-- %%
INSERT INTO demo.delta_lake.optimize_stock_prices
VALUES ('MSFT', 325.0, "2025-02-10");
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

-- %%
INSERT INTO demo.delta_lake.optimize_stock_prices
VALUES ('AMZN', 3520.0, "2025-02-12");
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

-- %% [markdown]
-- ### 3. Check the table history

-- %%
DESC HISTORY demo.delta_lake.optimize_stock_prices
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>7</td><td>2025-11-08T05:58:58Z</td><td>143298448758474</td><td>phildinhazure2011_gmail.com#ext#@phildinhazure2011gmail.onmicrosoft.com</td><td>VACUUM END</td><td>Map(status -> COMPLETED)</td><td>null</td><td>List(4199971308644649)</td><td>1102-054914-te7oizq7</td><td>6</td><td>SnapshotIsolation</td><td>true</td><td>Map(numDeletedFiles -> 0, numVacuumedDirectories -> 1)</td><td>null</td><td>Databricks-Runtime/16.4.x-photon-scala2.12</td></tr><tr><td>6</td><td>2025-11-08T05:58:51Z</td><td>143298448758474</td><td>phildinhazure2011_gmail.com#ext#@phildinhazure2011gmail.onmicrosoft.com</td><td>VACUUM START</td><td>Map(retentionCheckEnabled -> true, defaultRetentionMillis -> 604800000)</td><td>null</td><td>List(4199971308644649)</td><td>1102-054914-te7oizq7</td><td>5</td><td>SnapshotIsolation</td><td>true</td><td>Map(numFilesToDelete -> 0, sizeOfDataToDelete -> 0)</td><td>null</td><td>Databricks-Runtime/16.4.x-photon-scala2.12</td></tr><tr><td>5</td><td>2025-11-08T05:54:50Z</td><td>143298448758474</td><td>phildinhazure2011_gmail.com#ext#@phildinhazure2011gmail.onmicrosoft.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], auto -> false, clusterBy -> [], zOrderBy -> [], batchId -> 0)</td><td>null</td><td>List(4199971308644649)</td><td>1102-054914-te7oizq7</td><td>4</td><td>SnapshotIsolation</td><td>false</td><td>Map(numRemovedFiles -> 4, numRemovedBytes -> 4145, p25FileSize -> 1143, numDeletionVectorsRemoved -> 0, minFileSize -> 1143, numAddedFiles -> 1, maxFileSize -> 1143, p75FileSize -> 1143, p50FileSize -> 1143, numAddedBytes -> 1143)</td><td>null</td><td>Databricks-Runtime/16.4.x-photon-scala2.12</td></tr><tr><td>4</td><td>2025-11-08T05:53:14Z</td><td>143298448758474</td><td>phildinhazure2011_gmail.com#ext#@phildinhazure2011gmail.onmicrosoft.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> true, partitionBy -> [])</td><td>null</td><td>List(4199971308644649)</td><td>1102-054914-te7oizq7</td><td>3</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 1036)</td><td>null</td><td>Databricks-Runtime/16.4.x-photon-scala2.12</td></tr><tr><td>3</td><td>2025-11-08T05:53:13Z</td><td>143298448758474</td><td>phildinhazure2011_gmail.com#ext#@phildinhazure2011gmail.onmicrosoft.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> true, partitionBy -> [])</td><td>null</td><td>List(4199971308644649)</td><td>1102-054914-te7oizq7</td><td>2</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 1036)</td><td>null</td><td>Databricks-Runtime/16.4.x-photon-scala2.12</td></tr><tr><td>2</td><td>2025-11-08T05:53:12Z</td><td>143298448758474</td><td>phildinhazure2011_gmail.com#ext#@phildinhazure2011gmail.onmicrosoft.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(4199971308644649)</td><td>1102-054914-te7oizq7</td><td>1</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 1039)</td><td>null</td><td>Databricks-Runtime/16.4.x-photon-scala2.12</td></tr><tr><td>1</td><td>2025-11-08T05:53:11Z</td><td>143298448758474</td><td>phildinhazure2011_gmail.com#ext#@phildinhazure2011gmail.onmicrosoft.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> true, partitionBy -> [])</td><td>null</td><td>List(4199971308644649)</td><td>1102-054914-te7oizq7</td><td>0</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 1034)</td><td>null</td><td>Databricks-Runtime/16.4.x ...

-- %% [markdown]
-- ### 4. Check the number of files required to get the lastest data

-- %%
DESC DETAIL demo.delta_lake.optimize_stock_prices
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>clusteringColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th><th>tableFeatures</th><th>statistics</th><th>clusterByAuto</th></tr></thead><tbody><tr><td>delta</td><td>95fbb481-3e0a-434d-ae11-91c464b3ae1b</td><td>demo.delta_lake.optimize_stock_prices</td><td>null</td><td>abfss://demo@philproject1.dfs.core.windows.net/delta_lake/__unitystorage/schemas/96fe9421-7197-45dd-8263-de55761a1bab/tables/694230c4-53ba-42b9-b9fa-cae186a027e5</td><td>2025-11-08T05:52:05.819Z</td><td>2025-11-08T05:53:14Z</td><td>List()</td><td>List()</td><td>4</td><td>4145</td><td>Map(delta.parquet.compression.codec -> zstd, delta.enableDeletionVectors -> true)</td><td>3</td><td>7</td><td>List(appendOnly, deletionVectors, invariants)</td><td>Map(numRowsDeletedByDeletionVectors -> 0, numDeletionVectors -> 0)</td><td>false</td></tr></tbody></table></div>

-- %% [markdown]
-- ### 5.run OPTIMIZE

-- %%
OPTIMIZE demo.delta_lake.optimize_stock_prices
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>abfss://demo@philproject1.dfs.core.windows.net/delta_lake/__unitystorage/schemas/96fe9421-7197-45dd-8263-de55761a1bab/tables/694230c4-53ba-42b9-b9fa-cae186a027e5</td><td>List(1, 4, List(1143, 1143, 1143.0, 1, 1143), List(1034, 1039, 1036.25, 4, 4145), 0, null, null, 0, 1, 4, 0, true, 0, 0, 1762581288667, 1762581290987, 4, 1, null, List(0, 0), null, 3, 3, 320, 0, null)</td></tr></tbody></table></div>

-- %%
OPTIMIZE demo.delta_lake.optimize_stock_prices
ZORDER BY stock_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>abfss://demo@philproject1.dfs.core.windows.net/delta_lake/__unitystorage/schemas/96fe9421-7197-45dd-8263-de55761a1bab/tables/694230c4-53ba-42b9-b9fa-cae186a027e5</td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 0, List(minCubeSize(107374182400), List(0, 0), List(1, 1143), 0, List(0, 0), 0, null), null, 0, 0, 1, 1, false, 0, 0, 1762581401082, 1762581401619, 4, 0, null, List(0, 0), null, 3, 3, 0, 0, null)</td></tr></tbody></table></div>

-- %% [markdown]
-- ### 6.Remove unused file by VACCUM commands

-- %%
VACUUM demo.delta_lake.optimize_stock_prices
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td>abfss://demo@philproject1.dfs.core.windows.net/delta_lake/__unitystorage/schemas/96fe9421-7197-45dd-8263-de55761a1bab/tables/694230c4-53ba-42b9-b9fa-cae186a027e5</td></tr></tbody></table></div>
