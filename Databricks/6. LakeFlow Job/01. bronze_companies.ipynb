-- %% [markdown]
-- ## Ingest companies data into bronze layer
-- 1. Create the bronze schema if doesn't already exists
-- 1. Create the bronze companies table with the data from landing folder.

-- %%
CREATE SCHEMA IF NOT EXISTS demo.bronze
     MANAGED LOCATION 'abfss://demo@philproject1.dfs.core.windows.net/bronze';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
DROP TABLE IF EXISTS demo.bronze.companies;

CREATE TABLE demo.bronze.companies
AS
SELECT company_name, founded_date, country
  FROM read_files('abfss://demo@philproject1.dfs.core.windows.net/landing/companies',
                  format => 'csv',
                  header => true);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>
